# %% [markdown]
# # Yelp API Reviews - ETL Process

# %% [markdown]
# ---
#
# > *Functions, class, and methods generated by ChatGPT based on functions/workflow from prior notebook.*
#
# **Next Steps:**
#
# - Reintroduce the method(s) needed to get the business details beyond just the reviews.
# - Polish and optimize class/workflow.\
# - Add logging module for more advanced feedback and error monitoring.
#
# ---

# %%
import json

with open('.secrets.json') as f:
    keys = json.load(f)

client_id = keys['Client_ID']
yelp_key = keys['api_key']

# %%
import requests
import pandas as pd

def catch_api_errors(func):
    """Decorator to catch and report errors in API calls."""
    def wrapper(*args, **kwargs):
        try:
            return func(*args, **kwargs)
        except requests.exceptions.RequestException as e:
            print(f"API request error in {func.__name__}: {e}")
            return None
        except Exception as e:
            print(f"General error in {func.__name__}: {e}")
            return None
    return wrapper

class YelpReviewManager:
    def __init__(self, yelp_key):
        self._yelp_key = yelp_key
        self._base_url = 'https://api.yelp.com/v3/businesses'
    
    @catch_api_errors
    def _make_api_request(self, endpoint, params=None):
        """Make a private Yelp API request."""
        headers = {'Authorization': f'Bearer {self._yelp_key}'}
        response = requests.get(f"{self._base_url}/{endpoint}", headers=headers, params=params)
        response.raise_for_status()
        return response.json()

    def fetch_businesses(self, term, location):
        """Fetch businesses matching a search term and location."""
        print(f"Fetching businesses for term '{term}' and location '{location}'...")
        businesses = []
        params = {'term': term, 'location': location, 'limit': 50}
        while True:
            response = self._make_api_request('search', params=params)
            businesses.extend(response.get('businesses', []))
            if len(businesses) >= response.get('total', 0) or not response.get('businesses'):
                break
            params['offset'] = len(businesses)
        print(f"Found {len(businesses)} businesses.")
        return [business['id'] for business in businesses]

    @catch_api_errors
    def fetch_reviews_for_business(self, business_id):
        """Fetch reviews for a single business ID."""
        print(f"Fetching reviews for business ID: {business_id}")
        reviews_response = self._make_api_request(f"{business_id}/reviews")
        return reviews_response.get('reviews', [])

    def fetch_and_compile_reviews(self, list_of_biz_ids, file_name):
        """Compile reviews for a list of business IDs."""
        print(f"Compiling reviews for {len(list_of_biz_ids)} businesses...")
        all_reviews = []
        for business_id in list_of_biz_ids:
            reviews = self.fetch_reviews_for_business(business_id)
            for review in reviews:
                review_details = pd.DataFrame([{
                    'Business ID': business_id,
                    'Reviewer Name': review['user']['name'],
                    'Review Rating': review['rating'],
                    'Review Text': review['text'],
                    'Time Created': review['time_created']
                }])
                all_reviews.append(review_details)
        compiled_reviews = pd.concat(all_reviews, ignore_index=True) if all_reviews else pd.DataFrame()
        compiled_reviews.to_csv(file_name, index=False)
        print(f"Reviews data compiled and saved to {file_name}.")

    def fetch_reviews_for_search_term(self, term, location, file_name):
        """Fetch and compile reviews for businesses matching a search term and location."""
        business_ids = self.fetch_businesses(term, location)
        if business_ids:
            self.fetch_and_compile_reviews(business_ids, file_name)
        else:
            print(f"No businesses found for term '{term}' and location '{location}'. No reviews to compile.")

# %%
# Initialize the YelpReviewManager with your Yelp API key
yelp_review_manager = YelpReviewManager(yelp_key=yelp_key)

# Fetch and compile reviews for hotels in Lisbon, Portugal with one method call
yelp_review_manager.fetch_reviews_for_search_term(term='hotels', location='Lisbon, Portugal', file_name='./data/lisbon_hotels_reviews.csv')
# Out:
# Fetching businesses for term 'hotels' and location 'Lisbon, Portugal'...
# Found 268 businesses.
# Compiling reviews for 268 businesses...
# Fetching reviews for business ID: q-Px_TUI_zLr93xn-1-Ypw
# Fetching reviews for business ID: yvbBx06xhwEyvXITlGji5g
# Fetching reviews for business ID: 9wTTno6WG7cHlXDDZ00EQw
# Fetching reviews for business ID: fmoWlWBqkVeyFpTtcE09RQ
# Fetching reviews for business ID: DPkYK5RwCkAULtLJp7pOmA
# Fetching reviews for business ID: oWpzjQrPE02mTTqb3-QuRA
# Fetching reviews for business ID: UYTUME7WRO3Pz2ZiWaHCvQ
# Fetching reviews for business ID: kRJ7hWBHNyItC1R3s36utQ
# Fetching reviews for business ID: UNpztKHSE0A4iXnvDr2t1g
# Fetching reviews for business ID: 73rCWP_Cgj5c13bPm82IsQ
# Fetching reviews for business ID: kvFNVAOHH1MEP_2uJcO1Pg
# Fetching reviews for business ID: jBtK8qVZ-KlH37_NhIlaQw
# Fetching reviews for business ID: Yk6x3GErEUH9vXxdzmO5nQ
# Fetching reviews for business ID: Dds8XUKMlB6bmW3wHfyxtQ
# Fetching reviews for business ID: lIgc3taoaT4ZForepyUTqw
# Fetching reviews for business ID: H9Q1sJ0t4AZpJRM1DvOs3w
# Fetching reviews for business ID: nwBdT3UNgxwPc4-inOGkSw
# Fetching reviews for business ID: 1mkAYR_AlZeM_IkPmk-68A
# Fetching reviews for business ID: Ymx-nnEENCvo55ExfLpMiw
# Fetching reviews for business ID: b6bSO7KZQde5JdPem99RUg
# Fetching reviews for business ID: 9C4j9wot_OZgHx-LSzIg8w
# Fetching reviews for business ID: 3SPxa90mdRwMLdIySZFMsw
# Fetching reviews for business ID: j7aSumyYuKkLP1ZjrUUhMA
# Fetching reviews for business ID: -A0Yvm5x9xoTiExHJPseEA
# Fetching reviews for business ID: kz1oo1jVegg-9vWz3xfpKQ
# Fetching reviews for business ID: NJD2cy2VwKQighP2E9uJSw
# Fetching reviews for business ID: CW1gOMTDC5ZBnErrGx0yxw
# Fetching reviews for business ID: VjsO6GrOQDoC1qrF4cjJ6w
# Fetching reviews for business ID: 015YBPHeyIgjITEVjZShfA
# Fetching reviews for business ID: ud5jr6GocT-v6_BOSqtCtg
# Fetching reviews for business ID: _hWiNWd-EG5TTu3RvTxGWg
# Fetching reviews for business ID: cVgaf5yAQgvVlz1L4EROMw
# Fetching reviews for business ID: VDqVJhqbM-ot8rhvJY6N-g
# Fetching reviews for business ID: hLOIMUqiZpYmXq7Re_vhCg
# Fetching reviews for business ID: jZB4itjaySaxsJredM-QUg
# Fetching reviews for business ID: fQ5jbSMa2Mu2ozdDhKmx6Q
# Fetching reviews for business ID: KNBeo2aSxXtuMLJy9nkldg
# Fetching reviews for business ID: fU7Bg--A-3ndcgslmVMA7A
# Fetching reviews for business ID: 3twhTZpt-FdKNUw3pOti6A
# Fetching reviews for business ID: UMno67AjmqSKXX6xY5TmMA
# Fetching reviews for business ID: MnYLrGHe8ajtDWkDFa3O6A
# Fetching reviews for business ID: gLS7NknLeHkeQWA28xmtyw
# Fetching reviews for business ID: VBEE8AojX0VPAjJ54Cn2ig
# Fetching reviews for business ID: 2br-Hru6gwn1BzVIgTIijA
# Fetching reviews for business ID: U20ybTR0yXkRrjpXYkPY3w
# Fetching reviews for business ID: gaRcw3lcK5trqYwUFtVOwA
# Fetching reviews for business ID: uWdu6aSN036ckD6qlCnKMw
# Fetching reviews for business ID: EV2FHFqvMmW2j37EFDiOkw
# Fetching reviews for business ID: 8gynJfPXFO8RjqK1ImYsIw
# Fetching reviews for business ID: rHtY02rZl2GUVVHcoFUlfA
# Fetching reviews for business ID: 2O7oZ_7uhL9L09_oFJ0inA
# Fetching reviews for business ID: OsGOl9emBSsiIEy9q2ihXA
# Fetching reviews for business ID: DJgHLPzLclLpAp-_JnE7jA
# Fetching reviews for business ID: mKRIt5UqHOSDYQTNPv2BMg
# Fetching reviews for business ID: Ni-H5odi0iPh077OZgMrBQ
# Fetching reviews for business ID: XieXK380bk1DgOMzVJrhbQ
# Fetching reviews for business ID: MEiBpEXNhw6FaxX1n9gQSg
# Fetching reviews for business ID: 94Xd6GUngQ8IB7e3ww2P4g
# Fetching reviews for business ID: Ydmp0bv8rpmHsuBcSAo_tA
# Fetching reviews for business ID: o8zUAkYhk4jNNWU2n6y34w
# Fetching reviews for business ID: _ZBCoK0xNKw3NkQ21XArqg
# Fetching reviews for business ID: E3dR_DJ4ux1qBeAVIQPwOA
# Fetching reviews for business ID: mWOUCKU7GzC7imPDWErDLA
# Fetching reviews for business ID: UNBG8QgvPJJMmbKJhs70zg
# Fetching reviews for business ID: BExuGekqd19zjQccm4u-Cw
# Fetching reviews for business ID: p6vvtvMS_vS0j5TqdwlXIw
# Fetching reviews for business ID: PGc5eitSx0P1_8TAZrRAwQ
# Fetching reviews for business ID: KKrjlxdUl1449alcrPGPNA
# Fetching reviews for business ID: -jRm0HZitHkgIeWpY6gf7g
# Fetching reviews for business ID: 103gRKjPOy6WSukh-i24SQ
# Fetching reviews for business ID: mIpX6YzHIdsBasRKE39URw
# Fetching reviews for business ID: pX8HygTFVygCY2D06Z1GxA
# Fetching reviews for business ID: BAkLHeoo9Q2Zws0s8XzfoQ
# Fetching reviews for business ID: nZlPNKzqWLQ3649X6Y-4yg
# Fetching reviews for business ID: xWszm4ZmBs64YMGesoNGLQ
# Fetching reviews for business ID: elo3Hlpa55Y5lR1EnIeTHA
# Fetching reviews for business ID: XesfN49H0gvXlCAa0tupzg
# Fetching reviews for business ID: W4Mq62AKBL0Agz14NpOG0Q
# Fetching reviews for business ID: xyGtzlJabuxCk5X9XvHGyA
# Fetching reviews for business ID: 8JoDlYTeoyOAwdiXENngmg
# Fetching reviews for business ID: NeLujd9SRY_QKgmVbhbuKA
# Fetching reviews for business ID: _5PSrfIqOF7I3lU6kipdOQ
# Fetching reviews for business ID: khjtji8mBm_nzqVaNkavqg
# Fetching reviews for business ID: AVRA4b8NoJfyGomL36aAPg
# Fetching reviews for business ID: Ocr38bEw6Y_HFfgZzQm1pQ
# Fetching reviews for business ID: 8R5Let0C0xBhXX4e3AVUow
# Fetching reviews for business ID: nXtn_dGkfw2LTlC24AUhTg
# Fetching reviews for business ID: LoRz27RUAwGj9VWv7JFc3w
# Fetching reviews for business ID: MK7E3CGNm-fQ9yu193suHQ
# Fetching reviews for business ID: lxE12PdwtAg7FbmwWKUzuA
# Fetching reviews for business ID: k8DMDDSJh_oe4aF-zNSPzw
# Fetching reviews for business ID: 0gImdnad0zHv-QUb514LVg
# Fetching reviews for business ID: OMJjReMeZmmn8B6X_Au95g
# Fetching reviews for business ID: CM2i-1EqNq0us0rNeIajug
# Fetching reviews for business ID: o68huHfXtqmnowm8bgwM4g
# Fetching reviews for business ID: gtUWa7FlCf8y4Js_w_4T8g
# Fetching reviews for business ID: 98Vl4nkRw3sw5QnYw4grCQ
# Fetching reviews for business ID: Vzpwe92EuMeNohrhJJdSRQ
# Fetching reviews for business ID: dfbaCNNguqeBTWQowG5IfQ
# Fetching reviews for business ID: EspxM6zo_qISJ-LbMx_3Yw
# Fetching reviews for business ID: fq78pkHgLAC2lO6wxBQbKA
# Fetching reviews for business ID: keCJeX4b71jeml41tZ2crA
# Fetching reviews for business ID: hsbKI1M52LsyJJ695cvO6w
# Fetching reviews for business ID: gp_XbQaaC_0NYAbLCjdKyg
# Fetching reviews for business ID: nw41jSUNSdU5urQwtCTe7A
# Fetching reviews for business ID: rpYoYzbBc1apBsbsoF6qEg
# Fetching reviews for business ID: l2W5Z0j0r1kNlY_n9aHBTQ
# Fetching reviews for business ID: fPfQHF0bofk5K2rEkExiuQ
# Fetching reviews for business ID: iz-LQNeJAZwgj8dyw4H3jA
# Fetching reviews for business ID: UhGthz73WLiLXjEV_R8yrQ
# Fetching reviews for business ID: xlUvGYpA35aEVEjeGKr3cA
# Fetching reviews for business ID: eJJDnQ_S-7S-WMfbFOjbSA
# Fetching reviews for business ID: u4Nr18Agl9tLiV0z7-OxQg
# Fetching reviews for business ID: dOp79bY60loxGTdByyWxIw
# Fetching reviews for business ID: bakV-SwtQW3svi8YtRxsRw
# Fetching reviews for business ID: RZHSMuDwO1cQiN9YdOgxUA
# Fetching reviews for business ID: XXhSVTPVdKXwJPcEG0LEsw
# Fetching reviews for business ID: CPU8jOLO5qVX1zrep6OCOw
# Fetching reviews for business ID: f1VfTQ1qsvOHfsx4n50pfA
# Fetching reviews for business ID: EWIVrs6yBFZO0V6tK-F4Jw
# Fetching reviews for business ID: cVzSYVh5-Tbh7kEO6XHckQ
# Fetching reviews for business ID: MszBg4IsdOqZ_S01iDV77w
# Fetching reviews for business ID: 9OlPrcsvw5kwiRRMFGgixQ
# Fetching reviews for business ID: bUshm10f_MIEb17P7aj5ag
# Fetching reviews for business ID: eLn9GlY3xm19cUNDW1ptQg
# Fetching reviews for business ID: bu2QZ7i9fOWDN1Mv5hhSxw
# Fetching reviews for business ID: PewbnvrQpCfwWardKuHMZg
# Fetching reviews for business ID: 0jBAq6Yq3hTZhj42vAy6KA
# Fetching reviews for business ID: 9gHXEDPvCTVaqBx5iyhMGQ
# Fetching reviews for business ID: 6T8l_3JF1KIs3XmoWLvdlA
# Fetching reviews for business ID: uuXFpHAbn48d0umiVHsfBQ
# Fetching reviews for business ID: rGrYfpPzBecx3r8s27azdg
# Fetching reviews for business ID: a4x9K2UTSwLdDFe87WxmKg
# Reviews data compiled and saved to ./data/lisbon_hotels_reviews.csv.
